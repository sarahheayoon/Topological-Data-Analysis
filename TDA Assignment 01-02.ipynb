# %% [markdown]
# ### Coding Practices for Plotting Time-Series/ Spatial-Series Data (Assingment 01, 02)

# %%
import matplotlib.pyplot as plt
# ploting random (x,y) 
plt.plot([1,2,3,4],[1,5,1,0])
plt.xlabel('integers') #label
plt.show()

# %%
import numpy as np
# evenly sampled time at 0.2 intervals
t = np.arange(0, 5, 0.2) #from 0 to 5 with 0.2 intervals

# given function y = sin(t)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo') #'bo' is for the blue dots
plt.plot(t, y) #connected with lines
plt.show()

# %% [markdown]
# # Assignment 01
# ### For all values of t = 0, h, 2h, 3h, ..., 50h, plot all points (t, sin (t))
# - values of h = 0.01, 0.1, 1, 10, 0.57, pi, pi+0.1, 22/7
# - plot lines between them and without

# %%
# evenly sampled time at h interval where h = 0.01
t = np.arange(0, 0.5, 0.01)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 0.1
t = np.arange(0, 0.1*50, 0.1)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 1
t = np.arange(0, 1*50, 1)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 10
t = np.arange(0, 10*50, 10)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 0.47
t = np.arange(0, 0.47*50, 0.47)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = pi
import math
h = math.pi
t = np.arange(0, h*50, h)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# I expected just series of zeros since sin(pi) = 0 
# Is this an example of Lorezn butterflu effect? since math.pi is not an actual pi?

# %%
# evenly sampled time at h interval where h = pi+1
import math
h = math.pi + 1
t = np.arange(0,h*50, h)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()
# what a strange looking time series

# %%
# evenly sampled time at h interval where h = 22/7
h = 22/7
t = np.arange(0, h*50, h)
y = np.sin(t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %% [markdown]
# # Assignment 02: plot (sin(kh), sin((k+1)h)) for k = 0, 1, ..., 50
# - values of h = 0.01, 0.1, 1, 10, 0.57, pi, pi+0.1, 22/7
# - plot lines between them and without

# %% [markdown]
# question! is this particularly a meaningful graph??
# how is spatial series different from time series?

# %%
# evenly sampled time at h interval where h = 0.01
h = 0.01
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 0.1
h = 0.1
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 1
h = 1
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 10
h = 10
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 0.47
h = 0.47
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = pi
h = math.pi
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = pi+1
h = math.pi
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()

# %%
# evenly sampled time at h interval where h = 22/7
h = 22/7
k = np.arange(0, 50, 1)
t = np.arange(0, h*50, h)
x = np.sin(k*t)
y = np.sin((k+1)*t)

# plot t versus sin(t)
plt.plot(t, y, 'bo')
plt.plot(t, y)
plt.show()
